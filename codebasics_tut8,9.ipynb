# %%
import pandas as pd

# %%
india_weather= pd.DataFrame({
    'city': ['mumbai','delhi','bangalore'],
    'temperature': [80,60,78],
    'humidity':[32,45,30]
})
india_weather
# Out:
#         city  temperature  humidity
# 0     mumbai           80        32
# 1      delhi           60        45
# 2  bangalore           78        30

# %%
us_weather= pd.DataFrame({
    'city': ['newyork','chicago','orlando'],
    'temperature': [68,65,75],
    'humidity':[21,14,35]
})
us_weather
# Out:
#       city  temperature  humidity
# 0  newyork           68        21
# 1  chicago           65        14
# 2  orlando           75        35

# %%
df= pd.concat([india_weather,us_weather])
df
# Out:
#         city  temperature  humidity
# 0     mumbai           80        32
# 1      delhi           60        45
# 2  bangalore           78        30
# 0    newyork           68        21
# 1    chicago           65        14
# 2    orlando           75        35

# %%
df= pd.concat([india_weather,us_weather], ignore_index=True)
df
# Out:
#         city  temperature  humidity
# 0     mumbai           80        32
# 1      delhi           60        45
# 2  bangalore           78        30
# 3    newyork           68        21
# 4    chicago           65        14
# 5    orlando           75        35

# %%
df= pd.concat([india_weather,us_weather], keys= ['india','us'])
df
# Out:
#               city  temperature  humidity
# india 0     mumbai           80        32
#       1      delhi           60        45
#       2  bangalore           78        30
# us    0    newyork           68        21
#       1    chicago           65        14
#       2    orlando           75        35

# %%
df.loc["india"]
# Out:
#         city  temperature  humidity
# 0     mumbai           80        32
# 1      delhi           60        45
# 2  bangalore           78        30

# %%
temperature_df= pd.DataFrame({
    'city': ['mumbai','delhi','bangalore'],
    'temperature': [80,60,78]
})
temperature_df
# Out:
#         city  temperature
# 0     mumbai           80
# 1      delhi           60
# 2  bangalore           78

# %%
windspeed_df= pd.DataFrame({
    'city': ['mumbai','delhi','bangalore'],
    'humidity':[32,45,30]
})
windspeed_df
# Out:
#         city  humidity
# 0     mumbai        32
# 1      delhi        45
# 2  bangalore        30

# %%
df= pd.concat([temperature_df, windspeed_df], axis=1)
df
# Out:
#         city  temperature       city  humidity
# 0     mumbai           80     mumbai        32
# 1      delhi           60      delhi        45
# 2  bangalore           78  bangalore        30

# %%
temperature_df
# Out:
#         city  temperature
# 0     mumbai           80
# 1      delhi           60
# 2  bangalore           78

# %%
s= pd.Series(["Humid","Dry","Rainy"], name="event")
s
# Out:
# 0    Humid
# 1      Dry
# 2    Rainy
# Name: event, dtype: object

# %%
pd.concat([temperature_df, s], axis=1)
# Out:
#         city  temperature  event
# 0     mumbai           80  Humid
# 1      delhi           60    Dry
# 2  bangalore           78  Rainy

# %%
df1= pd.DataFrame({
    'city': ['newyork','chicago','orlando','baltimore'],
    'temperature': [21,14,35,42]
})
df1
# Out:
#         city  temperature
# 0    newyork           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           42

# %%
df2= pd.DataFrame({
    'city': ['chicago','newyork','san francisco'],
    'humidity': [65,68, 75]
})
df2
# Out:
#             city  humidity
# 0        chicago        65
# 1        newyork        68
# 2  san francisco        75

# %%
df3= pd.merge(df1, df2, on="city")
df3
# Out:
#       city  temperature  humidity
# 0  newyork           21        68
# 1  chicago           14        65

# %%
df3= pd.merge(df1, df2, on="city", how= "outer")
df3
# Out:
#             city  temperature  humidity
# 0        newyork         21.0      68.0
# 1        chicago         14.0      65.0
# 2        orlando         35.0       NaN
# 3      baltimore         42.0       NaN
# 4  san francisco          NaN      75.0

# %%
df3= pd.merge(df1, df2, on="city", how= "inner")
df3
# Out:
#       city  temperature  humidity
# 0  newyork           21        68
# 1  chicago           14        65

# %%
df3= pd.merge(df1, df2, on="city", how= "left")
df3
# Out:
#         city  temperature  humidity
# 0    newyork           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           42       NaN

# %%
df3= pd.merge(df1, df2, on="city", how= "right")
df3
# Out:
#             city  temperature  humidity
# 0        chicago         14.0        65
# 1        newyork         21.0        68
# 2  san francisco          NaN        75

# %%
df3= pd.merge(df1, df2, on="city", how= "outer", indicator= True)
df3
# Out:
#             city  temperature  humidity      _merge
# 0        newyork         21.0      68.0        both
# 1        chicago         14.0      65.0        both
# 2        orlando         35.0       NaN   left_only
# 3      baltimore         42.0       NaN   left_only
# 4  san francisco          NaN      75.0  right_only

# %%
df1= pd.DataFrame({
    'city': ['newyork','chicago','orlando','baltimore'],
    'temperature': [21,14,35,42],
    'humidity':[65,68,71,75]
})
df1
# Out:
#         city  temperature  humidity
# 0    newyork           21        65
# 1    chicago           14        68
# 2    orlando           35        71
# 3  baltimore           42        75

# %%
df2= pd.DataFrame({
    'city': ['chicago','newyork','san diego'],
    'humidity': [65,68, 75],
    'temperature':[21,14,35]
})
df2
# Out:
#         city  humidity  temperature
# 0    chicago        65           21
# 1    newyork        68           14
# 2  san diego        75           35

# %%
df3= pd.merge(df1,df2,on="city")
df3
# Out:
#       city  temperature_x  humidity_x  humidity_y  temperature_y
# 0  newyork             21          65          68             14
# 1  chicago             14          68          65             21

# %%
df3= pd.merge(df1,df2, on="city", suffixes=('_left','_right'))
df3
# Out:
#       city  temperature_left  humidity_left  humidity_right  temperature_right
# 0  newyork                21             65              68                 14
# 1  chicago                14             68              65                 21
